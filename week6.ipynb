# %% [markdown]
# # Week 6: Data Visualization in Python
#
# This week covers fundamental and intermediate data visualization techniques using `matplotlib` and `seaborn`.
#
# ---
#
# ## Learning Objectives
#
# - Create and customize plots using `matplotlib`
# - Use `seaborn` for statistical data visualization
# - Understand when to use different types of plots
# - Apply visualization techniques to explore data and communicate findings
#
# ---
#
# ## Topics Covered
#
# ### 1. Matplotlib Basics
# - `plt.plot()`, `plt.scatter()`, `plt.bar()`, `plt.hist()`
# - Titles, labels, legends
# - Subplots using `plt.subplot()` and `plt.subplots()`
# - Saving figures
#
# ### 2. Seaborn Essentials
# - `sns.histplot()`, `sns.boxplot()`
# - `sns.scatterplot()`, `sns.barplot()`
# - `sns.heatmap()` for correlation matrices
#
# ### 3. Plot Customization
# - Changing color palettes
# - Setting figure size, axis limits, ticks, and grid
# - Adding annotations
# ---
#
# ## Hands-On Exercise
#
# Dataset: Use the cleaned real estate dataset from Week 6.
#
# Tasks:
# - Histogram of `price` and `area`
# - Boxplot of `price` by `floor_level`
# - Scatterplot of `area` vs `price`, colored by number of bedrooms
# - Correlation heatmap
# - Countplot of number of listings by `floor_level`
#
# ---
#
# ## Resources
#
# - [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
# - [Seaborn Documentation](https://seaborn.pydata.org/)
# - [Python Graph Gallery](https://www.python-graph-gallery.com/)

# %% [markdown]
# # Data Cleaning

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

# %%
unclean_data = pd.read_csv("HDB_dataset.csv")
unclean_data.head()
# Out:
#    Unnamed: 0  resale_price  floor_area_sqm  Remaining_lease  \
# 0           0      395000.0            84.0               67
# 1           1      675000.0           146.0               66
# 2           2      413000.0           101.0               77
# 3           3      350000.0            64.0               65
# 4           4      728000.0           123.0               76
#
#    Dist_nearest_station  Dist_nearest_primary_school  Dist_nearest_GHawker  \
# 0              1.008453                     0.447115              0.482185
# 1              1.176052                     0.188651              1.930232
# 2              0.460362                     0.220392              3.662314
# 3              0.682939                     0.260424              0.676288
# 4              0.673447                     0.127896              0.972390
#
#     Dist_CBD   flat_type_category        storey_category
# 0   6.717383     flat_type_4.ROOM  storey_range_01.TO.03
# ...

# %%
unclean_data.shape
# Out:
# (6000, 10)

# %%
unclean_data.describe()
# Out:
#         Unnamed: 0  resale_price  floor_area_sqm  Remaining_lease  \
# count  6000.000000  6.000000e+03     6000.000000      6000.000000
# mean   2999.500000  4.974857e+05       98.578150        75.195500
# std    1732.195139  1.631647e+05       23.867782        14.327299
# min       0.000000  1.800000e+05       31.000000        45.000000
# 25%    1499.750000  3.800000e+05       84.000000        63.000000
# 50%    2999.500000  4.680000e+05       94.000000        75.000000
# 75%    4499.250000  5.850000e+05      113.000000        91.000000
# max    5999.000000  1.220000e+06      243.000000        97.000000
#
#        Dist_nearest_station  Dist_nearest_primary_school  \
# count           6000.000000                  6000.000000
# mean               0.606563                     0.403124
# std                0.390791                     0.241244
# min                0.022428                     0.050353
# 25%                0.297739                     0.230280
# ...

# %%
unclean_data.isnull().sum() # Check for any null values
# Out:
# Unnamed: 0                     0
# resale_price                   0
# floor_area_sqm                 0
# Remaining_lease                0
# Dist_nearest_station           0
# Dist_nearest_primary_school    0
# Dist_nearest_GHawker           0
# Dist_CBD                       0
# flat_type_category             0
# storey_category                0
# dtype: int64

# %%
unclean_data.columns
# Out:
# Index(['Unnamed: 0', 'resale_price', 'floor_area_sqm', 'Remaining_lease',
#        'Dist_nearest_station', 'Dist_nearest_primary_school',
#        'Dist_nearest_GHawker', 'Dist_CBD', 'flat_type_category',
#        'storey_category'],
#       dtype='object')

# %%
clean_data = unclean_data

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Histogram

# %%
# !pip install matplotlib
# !pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set figure size
plt.figure(figsize=(10,6))

# Create Histogram for resale prices
sns.histplot(clean_data["resale_price"], bins=20, color = "skyblue", kde = True)

# Labels and title
plt.xlabel("Resale Price")
plt.ylabel("Frequency")
plt.title("Distribution of Resale Prices")

# Show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Boxplot

# %%
# Set figure size
plt.figure(figsize=(8,6))

# Create box plot for resale prices
sns.boxplot(y=clean_data["resale_price"], color = "skyblue")

# Labels and Title
plt.ylabel("Resale Price")
plt.title("Distribution of HDB Resale Prices")

# Show plot
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Heatmap

# %%
clean_data.columns
# Out:
# Index(['Unnamed: 0', 'resale_price', 'floor_area_sqm', 'Remaining_lease',
#        'Dist_nearest_station', 'Dist_nearest_primary_school',
#        'Dist_nearest_GHawker', 'Dist_CBD', 'flat_type_category',
#        'storey_category'],
#       dtype='object')

# %%
# Start visualizing relationships between 2 numerical variables
numerical_features = [
    "resale_price",
    "floor_area_sqm",
    "Remaining_lease",
    "Dist_nearest_station",
    "Dist_nearest_primary_school",
    "Dist_nearest_GHawker",
    "Dist_CBD"
]

# %%
correlation_matrix = clean_data[numerical_features].corr()
correlation_matrix
# Out:
#                              resale_price  floor_area_sqm  Remaining_lease  \
# resale_price                     1.000000        0.631019         0.351046
# floor_area_sqm                   0.631019        1.000000         0.080392
# Remaining_lease                  0.351046        0.080392         1.000000
# Dist_nearest_station            -0.105646        0.045465        -0.229648
# Dist_nearest_primary_school     -0.005455       -0.080907        -0.116182
# Dist_nearest_GHawker            -0.051976        0.146675         0.571955
# Dist_CBD                        -0.269273        0.216244         0.297229
#
#                              Dist_nearest_station  \
# resale_price                            -0.105646
# floor_area_sqm                           0.045465
# Remaining_lease                         -0.229648
# Dist_nearest_station                     1.000000
# Dist_nearest_primary_school              0.226794
# Dist_nearest_GHawker                    -0.362359
# ...

# %%
plt.figure(figsize=(10,6))

sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation HeatMap of Continuous Features")
plt.show()

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(clean_data[numerical_features])  # Use only selected numerical features
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x="floor_area_sqm", y="resale_price", data=clean_data, alpha=0.5)

# Labels and title
plt.xlabel("Floor Area (sqm)")
plt.ylabel("Resale Price")
plt.title("Scatter Plot of Resale Price vs Floor Area")

# Show plot
plt.show()

# %%
clean_data.columns
# Out:
# Index(['Unnamed: 0', 'resale_price', 'floor_area_sqm', 'Remaining_lease',
#        'Dist_nearest_station', 'Dist_nearest_primary_school',
#        'Dist_nearest_GHawker', 'Dist_CBD', 'flat_type_category',
#        'storey_category'],
#       dtype='object')

# %%
# Define the correct order
flat_type_order = [
    "flat_type_1.ROOM",
    "flat_type_2.ROOM",
    "flat_type_3.ROOM",
    "flat_type_4.ROOM",
    "flat_type_5.ROOM",
    "flat_type_EXECUTIVE",
    "flat_type_MULTI.GENERATION"
]

# Ensure 'flat_type_category' exists
if "flat_type_category" not in clean_data.columns:
    categorical_features = clean_data.filter(like="flat_type_").columns
    clean_data["flat_type_category"] = clean_data[categorical_features].idxmax(axis=1)

# Convert to categorical with the correct order
clean_data["flat_type_category"] = pd.Categorical(clean_data["flat_type_category"],
                                                categories=flat_type_order,
                                                ordered=True)

# Plot the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(
    x="flat_type_category",
    y="resale_price",
    data=clean_data,  
    order=flat_type_order
)

plt.xticks(rotation=45)
plt.title("Resale Price by Flat Type (Ordered)")
plt.show()

# %%
clean_data.head()
# Out:
#    Unnamed: 0  resale_price  floor_area_sqm  Remaining_lease  \
# 0           0      395000.0            84.0               67
# 1           1      675000.0           146.0               66
# 2           2      413000.0           101.0               77
# 3           3      350000.0            64.0               65
# 4           4      728000.0           123.0               76
#
#    Dist_nearest_station  Dist_nearest_primary_school  Dist_nearest_GHawker  \
# 0              1.008453                     0.447115              0.482185
# 1              1.176052                     0.188651              1.930232
# 2              0.460362                     0.220392              3.662314
# 3              0.682939                     0.260424              0.676288
# 4              0.673447                     0.127896              0.972390
#
#     Dist_CBD   flat_type_category        storey_category
# 0   6.717383     flat_type_4.ROOM  storey_range_01.TO.03
# ...

# %%
# Define correct storey order manually
storey_order = [
    "storey_range_01.TO.03", "storey_range_04.TO.06", "storey_range_07.TO.09",
    "storey_range_10.TO.12", "storey_range_13.TO.15", "storey_range_16.TO.18",
    "storey_range_19.TO.21", "storey_range_22.TO.24", "storey_range_25.TO.27",
    "storey_range_28.TO.30", "storey_range_31.TO.33", "storey_range_34.TO.36",
    "storey_range_37.TO.39", "storey_range_40.TO.42", "storey_range_43.TO.45",
    "storey_range_46.TO.48"
]

# Convert column to categorical type with correct order
clean_data["storey_category"] = pd.Categorical(clean_data["storey_category"], categories=storey_order, ordered=True)

# Plot bar plot with correct ordering
plt.figure(figsize=(12, 6))
sns.barplot(x="storey_category", y="resale_price", data=clean_data, estimator=sum, ci=None, order=storey_order)

plt.xlabel("Storey Category")
plt.ylabel("Total Resale Price")
plt.title("Total Resale Price by Storey Category (Ordered)")
plt.xticks(rotation=45)  # Rotate for readability
plt.show()
# Out:
# C:\Users\eugen\AppData\Local\Temp\ipykernel_29648\2890815432.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="storey_category", y="resale_price", data=clean_data, estimator=sum, ci=None, order=storey_order)

# %%
# Create ordered box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="storey_category", y="resale_price", data=clean_data, order=storey_order)

# Labels and title
plt.xlabel("Storey Category")
plt.ylabel("Resale Price")
plt.title("Resale Price Distribution by Storey Category (Ordered)")
plt.xticks(rotation=45)  # Rotate for readability

plt.show()
# Higher Storey Categories Tend to Have Higher Resale Prices
# The median resale price (central line in each box) increases as the storey category increases.

# Many outliers (dots above the whiskers) appear in lower storey categories,
# indicating that some low-storey flats are sold at premium prices (possibly due to location, amenities, or size)

# Higher Storey Flats Show Greater Price Stability
# The whiskers (lines extending from the boxes) indicate the range of typical resale prices.
# For lower storey flats, the resale price range is quite large, indicating a
